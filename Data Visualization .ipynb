# %% [markdown]
# ## Data Visualization using Seaborn

# %% [markdown]
# Seaborn is a library that uses Matplotlib underneath to plot graphs

# %%
#importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/anura/Downloads/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.lineplot(x="SepalLengthCm",y="SepalWidthCm" , data=df, errorbar=None)
plt.show()

# %%
sns.lineplot(x="SepalLengthCm", y="SepalWidthCm" , data=df, hue="Species",errorbar=None)
plt.show()

# %%
#continous and categorical feature
sns.lineplot(x="SepalWidthCm", y="Species" , data=df, hue="Species",errorbar=None)
plt.show()

# %%
sns.lineplot(x="PetalLengthCm", y="Species" , data=df, hue="Species",errorbar=None)
plt.show()

# %%
#Scatter plot
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", data=df, hue="Species")
plt.title("Scatter plot")
plt.xlabel("Y")   #Custom X axis label
plt.show()

# %%
#Bar plot
sns.barplot(x="Species" , y="SepalLengthCm" , data=df, estimator="mean")
plt.show()

# %%
#Count Plot
sns.countplot(x="Species", data=df)
plt.show()

# %%
#Box plot or whisker plot
sns.boxplot(x="SepalWidthCm", data=df)
plt.show()

# %%
sns.boxplot(x="Species" , y="SepalWidthCm" , data=df)
plt.show()
#Checking outliers in each category with respect to sepal width

# %%
#Violin plot
#It provides a more advanced visualization than box plot
sns.violinplot(x="Species" , y="SepalWidthCm" , data=df)
plt.show()

# %%
j=pd.DataFrame({"marks":[3,6,8,9,10],"Age":[24,26,27,28,25],"Gender":["m","f","m","f","m"]})
j
# Out:
#    marks  Age Gender
# 0      3   24      m
# 1      6   26      f
# 2      8   27      m
# 3      9   28      f
# 4     10   25      m

# %%
sns.scatterplot(x="marks", y="Age", data=j, hue="Gender")
plt.title("Scatter Plot")
plt.xlabel("X")
plt.xlabel("Y")
plt.show()

# %%
#Strip Plot
# It basically screates a scatter plot based on category
sns.stripplot(x="Species", y="PetalLengthCm", data=df)
plt.show()

# %%
#Histogram
sns.histplot(x="PetalWidthCm", data=df, bins=4)
plt.show()

# %%
sns.histplot(x="PetalLengthCm", data=df, hue="Species", kde=True) #kernel density estimation
plt.show()
#kde is approximation of histogram to density curve

# %%
import warnings
warnings.filterwarnings("ignore")
sns.distplot(df["PetalWidthCm"],color="g")
plt.show()

# %%
d2 = df[["SepalLengthCm" , "SepalWidthCm" , "PetalLengthCm" , "PetalWidthCm" , "Species"]]

# %%
#PairPlot
#Creates a joint plot between every possible material
sns.pairplot(data=d2, hue="Species")
plt.show()

# %%
d2 = df[["SepalLengthCm" , "SepalWidthCm" , "PetalLengthCm" , "PetalWidthCm" , "Species"]]

# %%
#Categorical plot
sns.catplot(x="SepalLengthCm", data=df,kind="violin")
plt.show()

# %%
#The default representation of the data in catplot() uses a stripplot
sns.catplot(x="Species", y="SepalLengthCm", data=df, kind="swarm")
plt.show()

# %% [markdown]
# ## Correlation

# %%
#Comparing two values

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
tc=df.drop(columns = ["Id", "Species"], axis=1)

# %%
tc = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

# %%
##Heat map
## Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
## In this, to represent more common values or higher activities brighter colors basically reddish colors are used and 
## to represent less common or activity values, darker colors are preferred

# correlation between the different parameters 
tc = tc.corr()
  
tc
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(tc, annot = True)
plt.show()

# %%
sns.barplot(x='Species', y='SepalLengthCm', data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.boxplot(x='Species', y='SepalWidthCm', data=df)
plt.show()

# %%
## Violinplot
## It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel 
##density estimation to give a better description about the data distribution.

sns.violinplot(x='Species', y='SepalLengthCm', data=df)
plt.show()

##Stripplot
## It basically creates a scatter plot based on the category. 
# It is created using the stripplot()
sns.stripplot(x='Species', y='PetalWidthCm', data=df)
plt.show()



#The default representation of the data in catplot() uses a stripplot
sns.catplot(x='SepalLengthCm',y='Species',data=df)
plt.show()
